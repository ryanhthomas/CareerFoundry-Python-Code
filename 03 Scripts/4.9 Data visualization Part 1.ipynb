# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Wrangle the data
# 2. Quality checks
# 3. Combine and merge

# %% [markdown]
# ### Imports

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\rhtho\Documents\CareerFoundry\Data Immersion\Achievement 4\04-2023 Instacart Basket Analysis'
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %%
df.shape
# Out:
# (206209, 10)

# %% [markdown]
# ### Wrangle the data

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Rename columns
df.rename(columns={'Surnam':'Last Name','STATE':'State','n_dependants':'dependents','fam_status':'marital_status'},inplace=True)

# %%
# Confirm rename
df.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependents marital_status  income
# 0           3        married  165665
# 1           0         single   59285
# 2           2        married   99568
# 3           0         single   42049
# 4           1        married   40374

# %% [markdown]
# ### Quality checks

# %%
# Check data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         206209 non-null  int64
#  1   First Name      194950 non-null  object
#  2   Last Name       206209 non-null  object
#  3   Gender          206209 non-null  object
#  4   State           206209 non-null  object
#  5   Age             206209 non-null  int64
#  6   date_joined     206209 non-null  object
#  7   dependents      206209 non-null  int64
#  8   marital_status  206209 non-null  object
#  9   income          206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
# Check for mixed data types
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
# Convert column to string type
df['First Name'] = df['First Name'].astype('str')

# %%
# Check again for mixed data types
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# user_id           0
# First Name        0
# Last Name         0
# Gender            0
# State             0
# Age               0
# date_joined       0
# dependents        0
# marital_status    0
# income            0
# dtype: int64

# %% [markdown]
# No missing values exist

# %%
# Check for duplicate values
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, dependents, marital_status, income]
# Index: []

# %% [markdown]
# No duplicates exist

# %% [markdown]
# ### Combine and merge

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4.9.1.pkl'))

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 23 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   order_id                       int64
#  1   user_id                        int64
#  2   eval_set                       object
#  3   order_number                   int64
#  4   order_dow                      int64
#  5   order_hour_of_day              int64
#  6   days_since_prior_order         float64
#  7   product_id                     int64
#  8   add_to_cart_order              int64
#  9   reordered                      int64
#  10  product_name                   object
#  11  aisle_id                       int64
#  12  department_id                  int64
#  13  prices                         float64
#  14  price_range_loc                object
#  15  busiest_days                   object
#  16  busiest_period_of_day          object
# ...

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     7.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   prices    price_range_loc  busiest_days  busiest_period_of_day max_order  \
# ...

# %% [markdown]
# Merge on user_id.  Data types match

# %%
# Merge dataframes
df_merged_large = ords_prods_merge.merge(df, on = 'user_id', indicator = True)

# %%
# Export pickle
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_4.9_1.pkl'))

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     7.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   First Name  Last Name  Gender    State Age date_joined dependents  \
# ...
